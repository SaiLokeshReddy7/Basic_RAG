# %%
## Retrieval augmented generation (RAG)


import os
from dotenv import load_dotenv
load_dotenv()
import os.path
from llama_index.legacy import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)
from llama_index.legacy.retrievers import VectorIndexRetriever
from llama_index.legacy.query_engine import RetrieverQueryEngine 
from llama_index.legacy.postprocessor import SimilarityPostprocessor

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
# from llama_index.core import VectorStoreIndex,
from llama_index.legacy import VectorStoreIndex,SimpleDirectoryReader
documents=SimpleDirectoryReader("data").load_data()

# %%
documents
# Out:
# [Document(id_='ce1deba1-285c-41e6-9464-4d253093ca5a', embedding=None, metadata={'file_path': 'data\\POC_data.txt', 'file_name': 'POC_data.txt', 'file_type': 'text/plain', 'file_size': 11780, 'creation_date': '2024-07-28', 'last_modified_date': '2024-07-28', 'last_accessed_date': '2024-07-28'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='## Proof of Concept (POC): A Comprehensive Guide\n\n### Introduction\n\nA Proof of Concept (POC) is a crucial step in the project development process. It is an experiment or pilot project designed to determine if an idea can be turned into a reality. A POC aims to demonstrate the feasibility of a concept or idea, validating that it is viable and practical before significant resources are invested. This article will delve into the importance of a POC, its benefits, how to create one, and real-world examples.\n\n### Importance of a POC\n\n1. **Feasibility Validation**: A POC helps to verify that an idea or concept can be developed and implemented successfully. It ensures that the project is technically feasible and can meet the desired objectives.\n\n2. **Risk Mitigation**: By identifying potential issues early in the development process, a POC helps mitigate risks. It allows stakeholders to address any technical or operational challenges before full-scale development begins.\n\n3. **Resource Optimization**: Conducting a POC ensures that resources, including time, money, and manpower, are not wasted on unfeasible projects. It helps in making informed decisions about whether to proceed with the project.\n\n4. **Stakeholder Confidence**: A successful POC can boost stakeholder confidence in the project. It provides tangible evidence that the concept works and that the team has the capability to deliver the final product.\n\n### Benefits of a POC\n\n1. **Cost-Effective**: By identifying potential issues early, a POC can save significant costs associated with project failures. It allows for adjustments before large-scale investments are made.\n\n2. **Improved Project Planning**: Insights gained from a POC can improve project planning and execution. It helps in refining project requirements, timelines, and resource allocation.\n\n3. **Enhanced Innovation**: POCs encourage innovation by allowing teams to experiment with new ideas and technologies in a low-risk environment. This can lead to the development of unique solutions and competitive advantages.\n\n4. **Market Validation**: For commercial projects, a POC can provide market validation. It allows for testing the concept with a target audience, gathering feedback, and making necessary adjustments before a full launch.\n\n### How to Create a POC\n\n1. **Define Objectives**: Clearly outline the goals and objectives of the POC. What specific aspect of the project are you trying to validate? What are the success criteria?\n\n2. **Identify Key Stakeholders**: Determine who needs to be involved in the POC. This includes project managers, technical leads, end-users, and other relevant stakeholders.\n\n3. **Develop a Plan**: Create a detailed plan for the POC, including timelines, resources, and milestones. Ensure that the plan is realistic and achievable within the given constraints.\n\n4. **Build a Prototype**: Develop a prototype or a minimal viable product (MVP) that demonstrates the core functionality of the concept. Focus on critical features that need to be validated.\n\n5. **Conduct Testing**: Test the prototype thoroughly to ensure it meets the defined objectives. Gather feedback from stakeholders and end-users to identify any issues or areas for improvement.\n\n6. **Analyze Results**: Analyze the results of the POC to determine if the concept is feasible. Document any findings, including technical challenges, us ...

# %%
index = VectorStoreIndex.from_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 index= VectorStoreIndex.from_documents(documents)
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\base.py:111, in BaseIndex.from_documents(cls, documents, storage_context, service_context, show_progress, **kwargs)
#     102     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     104 nodes = run_transformations(
#     105     documents,  # type: ignore
#     106     service_context.transformations,
#     107     show_progress=show_progress,
#     108     **kwargs,
#     109 )
# --> 111 return cls(
#     112     nodes=nodes,
#     113     storage_context=storage_context,
#     114     service_context=service_context,
#     115     show_progress=show_progress,
#     116     **kwargs,
#     117 )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\vector_store\base.py:54, in VectorStoreIndex.__init__(self, nodes, objects, index_struct, service_context, storage_context, use_async, store_nodes_override, insert_batch_size, show_progress, **kwargs)
#      52 self._store_nodes_override = store_nodes_override
#      53 self._insert_batch_size = insert_batch_size
# ---> 54 super().__init__(
#      55     nodes=nodes,
#      56     index_struct=index_struct,
#      57     service_context=service_context,
#      58     storage_context=storage_context,
#      59     show_progress=show_progress,
#      60     objects=objects,
#      61     **kwargs,
#      62 )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\base.py:74, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, service_context, show_progress, **kwargs)
#      72 if index_struct is None:
#      73     nodes = nodes or []
# ---> 74     index_struct = self.build_index_from_nodes(
#      75         nodes + objects  # type: ignore
#      76     )
#      77 self._index_struct = index_struct
#      78 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\vector_store\base.py:277, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     269 if any(
#     270     node.get_content(metadata_mode=MetadataMode.EMBED) == "" for node in nodes
#     271 ):
#     272     raise ValueError(
#     273         "Cannot build index from nodes with no content. "
#     274         "Please ensure all nodes have content."
#     275     )
# --> 277 return self._build_index_from_nodes(nodes, **insert_kwargs)
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\vector_store\base.py:249, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     247     run_async_tasks(tasks)
#     248 else:
# --> 249     self._add_nodes_to_index(
#     250         index_struct,
#     251         nodes,
#     252         show_progress=self._show_progress,
#     253         **insert_kwargs,
#     254     )
#     255 return index_struct
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\vector_store\base.py:202, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     199     return
#     201 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 202     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     203     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     205     if not self._vector_store.stores_text or self._store_nodes_override:
#     206         # NOTE: if the vector store doesn't store text,
#     207         # we need to add the nodes to the index struct and document store
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\vector_store\base.py:110, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#      99 def _get_node_with_embedding(
#     100     self,
#     101     nodes: Sequence[BaseNode],
#     102     show_progress: bool = False,
#     103 ) -> List[BaseNode]:
#     104     """Get tuples of id, node, and embedding.
#     105
#     106     Allows us to store these nodes in a vector store.
#     107     Embeddings are called in batches.
#     108
#     109     """
# --> 110     id_to_embed_map = embed_nodes(
#     111         nodes, self._service_context.embed_model, show_progress=show_progress
#     112     )
#     114     results = []
#     115     for node in nodes:
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\indices\utils.py:138, in embed_nodes(nodes, embed_model, show_progress)
#     135     else:
#     136         id_to_embed_map[node.node_id] = node.embedding
# --> 138 new_embeddings = embed_model.get_text_embedding_batch(
#     139     texts_to_embed, show_progress=show_progress
#     140 )
#     142 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     143     id_to_embed_map[new_id] = text_embedding
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\core\embeddings\base.py:256, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     250 if idx == len(texts) - 1 or len(cur_batch) == self.embed_batch_size:
#     251     # flush
#     252     with self.callback_manager.event(
#     253         CBEventType.EMBEDDING,
#     254         payload={EventPayload.SERIALIZED: self.to_dict()},
#     255     ) as event:
# --> 256         embeddings = self._get_text_embeddings(cur_batch)
#     257         result_embeddings.extend(embeddings)
#     258         event.on_end(
#     259             payload={
#     260                 EventPayload.CHUNKS: cur_batch,
#     261                 EventPayload.EMBEDDINGS: embeddings,
#     262             },
#     263         )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\embeddings\openai.py:413, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     406 """Get text embeddings.
#     407
#     408 By default, this is a wrapper around _get_text_embedding.
#     409 Can be overridden for batch queries.
#     410
#     411 """
#     412 client = self._get_client()
# --> 413 return get_embeddings(
#     414     client,
#     415     texts,
#     416     engine=self._text_engine,
#     417     **self.additional_kwargs,
#     418 )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\tenacity\__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\tenacity\__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\concurrent\futures\_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\concurrent\futures\_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\llama_index\legacy\embeddings\openai.py:178, in get_embeddings(client, list_of_text, engine, **kwargs)
#     174 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     176 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 178 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     179 return [d.embedding for d in data]
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\resources\embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
#     [... skipping similar frames: SyncAPIClient._request at line 1031 (7 times), SyncAPIClient._retry_request at line 1079 (7 times)]
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File c:\Ml project practice\RAG LLM End to End\RAG_LLM_END_TO_END\venv\lib\site-packages\openai\_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 index
#
# NameError: name 'index' is not defined

# %%
query_engine=index.as_query_engine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 query_engine=index.as_query_engine()
#
# NameError: name 'index' is not defined

# %%
retriever = VectorIndexRetriever(index=index,similarity_top_k=4)
postprocessor = SimilarityPostprocessor(similarity_cutoff=0.80)
query_engine = RetrieverQueryEngine(retriever=retriever, node_postprocessors=[postprocessor])

# %%
response = query_engine.qurey("what is a POC")

# %%
response

# %%
from llama_index.legacy.response.pprint_utils import pprint_response

pprint_response(response)
print(response)

# %%
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):

    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents)
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

query_engine = index.as_query_engine()
response = query_engine.query("What are transformers?")
print(response)
